# %% [markdown]
# **Laboratorio 3 metodos numericos**

# %% [markdown]
# LINK:https://www.linkedin.com/in/miguel-angel-chicaiza-guzman-a80816188/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
